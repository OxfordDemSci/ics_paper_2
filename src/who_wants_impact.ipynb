# %%
import pandas as pd
from model_helpers import run_OLS
from figure_helpers import make_figure_one
make_figure_one()

# %% [markdown]
# Now lets build some models.

# %%
df = pd.read_csv('../data/wrangled/df_clean_merged.csv')

# %%
run_OLS(df, 'Q10', ['Q5_binary'])
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                    Q10   R-squared:                       0.002
# Model:                            OLS   Adj. R-squared:                 -0.000
# Method:                 Least Squares   F-statistic:                    0.8779
# Date:                Sun, 23 Feb 2025   Prob (F-statistic):              0.349
# Time:                        17:37:06   Log-Likelihood:                -1443.5
# No. Observations:                 380   AIC:                             2891.
# Df Residuals:                     378   BIC:                             2899.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         24.6840      0.744     33.185      0.000      23.221      26.147
# ...

# %%
run_OLS(df, 'Q10', ['Q8_stemshape_binary'])
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                    Q10   R-squared:                       0.032
# Model:                            OLS   Adj. R-squared:                  0.029
# Method:                 Least Squares   F-statistic:                     12.22
# Date:                Sun, 23 Feb 2025   Prob (F-statistic):           0.000529
# Time:                        17:37:06   Log-Likelihood:                -1403.5
# No. Observations:                 373   AIC:                             2811.
# Df Residuals:                     371   BIC:                             2819.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                           coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# const                  23.6972      0.660     35.927      0.000      22.400      24.994
# ...

# %%
run_OLS(df, 'Q10', ['Q4_years'])
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                    Q10   R-squared:                       0.018
# Model:                            OLS   Adj. R-squared:                  0.016
# Method:                 Least Squares   F-statistic:                     7.231
# Date:                Sun, 23 Feb 2025   Prob (F-statistic):            0.00747
# Time:                        17:37:06   Log-Likelihood:                -1482.0
# No. Observations:                 391   AIC:                             2968.
# Df Residuals:                     389   BIC:                             2976.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         29.6373      1.784     16.609      0.000      26.129      33.146
# ...

# %%
run_OLS(df, 'Q10', ['Q5_binary', 'Q8_stemshape_binary'])
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                    Q10   R-squared:                       0.041
# Model:                            OLS   Adj. R-squared:                  0.036
# Method:                 Least Squares   F-statistic:                     7.700
# Date:                Sun, 23 Feb 2025   Prob (F-statistic):           0.000532
# Time:                        17:37:06   Log-Likelihood:                -1360.3
# No. Observations:                 362   AIC:                             2727.
# Df Residuals:                     359   BIC:                             2738.
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                           coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# const                  22.7925      0.859     26.533      0.000      21.103      24.482
# ...

# %%
run_OLS(df, 'Q10', ['Q5_binary', 'Q4_years'])
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                    Q10   R-squared:                       0.021
# Model:                            OLS   Adj. R-squared:                  0.016
# Method:                 Least Squares   F-statistic:                     4.109
# Date:                Sun, 23 Feb 2025   Prob (F-statistic):             0.0172
# Time:                        17:37:06   Log-Likelihood:                -1439.8
# No. Observations:                 380   AIC:                             2886.
# Df Residuals:                     377   BIC:                             2897.
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         29.6025      1.961     15.093      0.000      25.746      33.459
# ...

# %%
run_OLS(df, 'Q10', ['Q4_years', 'Q8_stemshape_binary'])
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                    Q10   R-squared:                       0.058
# Model:                            OLS   Adj. R-squared:                  0.052
# Method:                 Least Squares   F-statistic:                     11.29
# Date:                Sun, 23 Feb 2025   Prob (F-statistic):           1.74e-05
# Time:                        17:37:06   Log-Likelihood:                -1398.5
# No. Observations:                 373   AIC:                             2803.
# Df Residuals:                     370   BIC:                             2815.
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                           coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# const                  29.0269      1.802     16.104      0.000      25.483      32.571
# ...

# %%
run_OLS(df, 'Q10', ['Q5_binary', 'Q4_years', 'Q8_stemshape_binary'])
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                    Q10   R-squared:                       0.067
# Model:                            OLS   Adj. R-squared:                  0.059
# Method:                 Least Squares   F-statistic:                     8.518
# Date:                Sun, 23 Feb 2025   Prob (F-statistic):           1.77e-05
# Time:                        17:37:07   Log-Likelihood:                -1355.4
# No. Observations:                 362   AIC:                             2719.
# Df Residuals:                     358   BIC:                             2734.
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                           coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# const                  28.3617      1.973     14.375      0.000      24.482      32.242
# ...

# %%
run_OLS(df, 'Q10', ['Q5_binary', 'Q4_years', 'Q8_stemshape_binary', 'is_russell'])
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                    Q10   R-squared:                       0.072
# Model:                            OLS   Adj. R-squared:                  0.061
# Method:                 Least Squares   F-statistic:                     6.497
# Date:                Sun, 23 Feb 2025   Prob (F-statistic):           4.79e-05
# Time:                        17:37:07   Log-Likelihood:                -1279.7
# No. Observations:                 341   AIC:                             2569.
# Df Residuals:                     336   BIC:                             2589.
# Df Model:                           4
# Covariance Type:            nonrobust
# ...
#                           coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# const                  28.9006      2.132     13.554      0.000      24.706      33.095
# ...

# %%
run_OLS(df, 'Q10', ['Q5_binary', 'Q4_years', 'Q8_stemshape_binary', 'fte'])
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                    Q10   R-squared:                       0.055
# Model:                            OLS   Adj. R-squared:                  0.042
# Method:                 Least Squares   F-statistic:                     4.249
# Date:                Sun, 23 Feb 2025   Prob (F-statistic):            0.00234
# Time:                        17:37:07   Log-Likelihood:                -1103.0
# No. Observations:                 295   AIC:                             2216.
# Df Residuals:                     290   BIC:                             2234.
# Df Model:                           4
# Covariance Type:            nonrobust
# ...
#                           coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# const                  27.8700      2.314     12.045      0.000      23.316      32.424
# ...

# %%
run_OLS(df, 'Q10', ['Q5_binary', 'Q4_years', 'Q8_stemshape_binary', 'is_russell', 'fte'])
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                    Q10   R-squared:                       0.064
# Model:                            OLS   Adj. R-squared:                  0.048
# Method:                 Least Squares   F-statistic:                     3.979
# Date:                Sun, 23 Feb 2025   Prob (F-statistic):            0.00166
# Time:                        17:37:07   Log-Likelihood:                -1101.6
# No. Observations:                 295   AIC:                             2215.
# Df Residuals:                     289   BIC:                             2237.
# Df Model:                           5
# Covariance Type:            nonrobust
# ...
#                           coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# const                  27.7932      2.307     12.046      0.000      23.252      32.334
# ...

# %%
run_OLS(df, 'Q10', ['Q5_binary', 'Q4_years', 'Q8_stemshape_binary', 'ICS_GPA'])
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                    Q10   R-squared:                       0.055
# Model:                            OLS   Adj. R-squared:                  0.042
# Method:                 Least Squares   F-statistic:                     4.201
# Date:                Sun, 23 Feb 2025   Prob (F-statistic):            0.00254
# Time:                        17:37:07   Log-Likelihood:                -1099.8
# No. Observations:                 294   AIC:                             2210.
# Df Residuals:                     289   BIC:                             2228.
# Df Model:                           4
# Covariance Type:            nonrobust
# ...
#                           coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# const                  22.1587      5.438      4.075      0.000      11.456      32.861
# ...

# %%
run_OLS(df, 'Q10', ['Q5_binary', 'Q4_years', 'Q8_stemshape_binary', 'is_russell', 'ICS_GPA'])
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                    Q10   R-squared:                       0.064
# Model:                            OLS   Adj. R-squared:                  0.048
# Method:                 Least Squares   F-statistic:                     3.927
# Date:                Sun, 23 Feb 2025   Prob (F-statistic):            0.00185
# Time:                        17:37:07   Log-Likelihood:                -1098.4
# No. Observations:                 294   AIC:                             2209.
# Df Residuals:                     288   BIC:                             2231.
# Df Model:                           5
# Covariance Type:            nonrobust
# ...
#                           coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# const                  20.3996      5.525      3.692      0.000       9.525      31.274
# ...

# %%
run_OLS(df, 'Q10', ['Q5_binary', 'Q4_years', 'Q8_stemshape_binary', 'tot_income'])
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                    Q10   R-squared:                       0.050
# Model:                            OLS   Adj. R-squared:                  0.037
# Method:                 Least Squares   F-statistic:                     3.835
# Date:                Sun, 23 Feb 2025   Prob (F-statistic):            0.00470
# Time:                        17:37:07   Log-Likelihood:                -1103.8
# No. Observations:                 295   AIC:                             2218.
# Df Residuals:                     290   BIC:                             2236.
# Df Model:                           4
# Covariance Type:            nonrobust
# ...
#                           coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# const                  28.3813      2.311     12.283      0.000      23.834      32.929
# ...

# %%
run_OLS(df, 'Q10', ['Q5_binary', 'Q4_years', 'Q8_stemshape_binary', 'is_russell', 'tot_income'])
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                    Q10   R-squared:                       0.057
# Model:                            OLS   Adj. R-squared:                  0.040
# Method:                 Least Squares   F-statistic:                     3.478
# Date:                Sun, 23 Feb 2025   Prob (F-statistic):            0.00455
# Time:                        17:37:07   Log-Likelihood:                -1102.8
# No. Observations:                 295   AIC:                             2218.
# Df Residuals:                     289   BIC:                             2240.
# Df Model:                           5
# Covariance Type:            nonrobust
# ...
#                           coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# const                  28.4681      2.307     12.337      0.000      23.927      33.010
# ...
